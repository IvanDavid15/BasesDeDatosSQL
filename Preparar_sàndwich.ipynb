# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanDavid15/BasesDeDatosSQL/blob/main/Preparar_s%C3%A0ndwich.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Algoritmo para preparan un sàndwich de jamòn y queso
print("Preparar un sándwich")

pan = "2 rebanas de pan"
jamon = "1 rebanada de jamón"
queso = "1 rebana de queso"
lechuga = "1 rebanada de luchuga"

print("Tomando",pan)
print("colocar la primera rebanada de pan")
print("Colocando",jamon, "sobre el pan")
print("Colocando" , queso, "sobre el jamon")
print("colocando una hoja de lechuga sobre el queso")
print("colocando la segunda rebanada de pan")
print("Cortando el Sàndwich por la mitad(opcional)")
print("Sirviendo el sàndwich en un plato")

print("Sàndiwch preparado")
# Out:
# Preparar un sándwich
# Tomando 2 rebanas de pan
# colocar la primera rebanada de pan
# Colocando 1 rebanada de jamón sobre el pan
# Colocando 1 rebana de queso sobre el jamon
# colocando una hoja de lechuga sobre el queso
# colocando la segunda rebanada de pan
# Cortando el Sàndwich por la mitad(opcional)
# Sirviendo el sàndwich en un plato
# Sàndiwch preparado

# %%
#Algoritmo para preparan un sàndwich de jamòn y queso

print("INICIO")

#Entradas
pan = 2
jamon = 1
queso = 1
lechuga = 1
Salsa_de_Tomate = 1
Aros_De_Cebolla = 1

print ("Entradas:")
print ("- Pan")
print ("- Jamòn")
print ("- Queso")
print ("- Lechuga")
print ("- Salsa de tomate")
print ("- Aros de cebolla")


#Pasos del algortimo

print("\npaso 1: dos rebanadas de pan.")
print("paso 2: colocar una rebanada de jamon en una rabanada de pan.")
print("paso 3: colocar una rebana de queso sobre el jamon.")
print("paso 4: colocar una hoja de lechuga sobre el queso.")
print("Paso 5: agregar salsa de tomate sobre la lechuga.")
print("Paso 6: agregar aros de cebolla sobre la salsa.")
print("paso 7: colocar la segunda rebanada de pan sobre la lechuga.")

#Decision de cortar
cortar = input("¿Desea cortar el sándwich? (si/no): ")

if cortar == "si":
    print("Paso 8: Cortar el sándwich por la mitad")

else:
    print("Paso 9: No cortar el sàndwich")

print("Paso 10: Servir el Sàndwich en el plato")

#salida
print("\nSalida:")
print("Sàndwich preparado")

print("FIN")
# Out:
# INICIO
# Entradas:
# - Pan
# - Jamòn
# - Queso
# - Lechuga
# - Salsa de tomate
# - Aros de cebolla
#
# paso 1: dos rebanadas de pan.
# paso 2: colocar una rebanada de jamon en una rabanada de pan.
# paso 3: colocar una rebana de queso sobre el jamon.
# paso 4: colocar una hoja de lechuga sobre el queso.
# Paso 5: agregar salsa de tomate sobre la lechuga.
# Paso 6: agregar aros de cebolla sobre la salsa.
# paso 7: colocar la segunda rebanada de pan sobre la lechuga.
# ¿Desea cortar el sándwich? (si/no): no
# Paso 9: No cortar el sàndwich
# Paso 10: Servir el Sàndwich en el plato
#
# Salida:
# Sàndwich preparado
# FIN
